# %% [markdown]
# # Day 3: Advanced Hyperparameter Tuning with Bayesian Optimization
#
# ---
#
# ## Introduction to Hyperparameter Tuning
#
# Hyperparameters are configuration parameters external to the model, such as learning rate, number of layers, or maximum depth. Hyperparameter tuning is the process of finding the best combination of these parameters to improve model performance.
#
# ---
#
# ## What is Bayesian Optimization?
#
# Bayesian Optimization is an efficient technique for optimizing objective functions that are:
# - Expensive to evaluate
# - Have no known closed-form expression
# - Potentially noisy or non-convex
#
# It uses a probabilistic surrogate model to model the objective function and an acquisition function to decide where to sample next.
#
# ---
#
# ## Key Components of Bayesian Optimization
#
# 1. *Surrogate Model*:
#    - A probabilistic model such as a Gaussian Process (GP)
#    - Approximates the true objective function
#
# 2. *Acquisition Function*:
#    - Guides the optimization by balancing exploration and exploitation
#    - Examples: Expected Improvement (EI), Probability of Improvement (PI), Upper Confidence Bound (UCB)
#
# 3. *Iterative Refinement*:
#    - After evaluating new hyperparameters, the surrogate model is updated
#    - This improves accuracy over time
#
# ---
#
# ## Why Use Bayesian Optimization?
#
# - More sample-efficient than grid or random search
# - Suitable for high-dimensional search spaces
# - Reduces the number of required evaluations
# - Especially effective when evaluations are expensive or time-consuming
#
# ---
#
# ## Exploration vs. Exploitation
#
# | Strategy       | Description                                     | Purpose                          |
# |----------------|-------------------------------------------------|----------------------------------|
# | Exploration    | Samples from less-known or unvisited regions    | Finds new potentially good areas |
# | Exploitation   | Samples near previously known good results      | Fine-tunes existing good areas   |
#
# Bayesian Optimization balances both using the acquisition function.
#
# ---
#
# ## Unified Example: Minimizing a Simple Objective Function
#
# We will demonstrate Bayesian Optimization using two libraries: *Hyperopt* and *Optuna*. The goal is to minimize a simple quadratic function:
#
# *Objective function:*
# \[
# f(x) = (x - 3)^2 + 1
# \]
#
# ### Using Hyperopt
#
# ```python
# from hyperopt import fmin, tpe, hp, Trials
# import numpy as np
#
# # Define the objective function
# def objective(params):
#     x = params['x']
#     return (x - 3)**2 + 1
#
# # Define the search space
# space = {'x': hp.uniform('x', -10, 10)}
#
# # Run Bayesian Optimization using Hyperopt
# trials = Trials()
# best = fmin(
#     fn=objective,
#     space=space,
#     algo=tpe.suggest,
#     max_evals=50,
#     trials=trials
# )
#
# print("Best parameters from Hyperopt:", best)
# ```
# ### Using Optuna
# ```python
# import optuna
#
# # Define the objective function
# def objective(trial):
#     x = trial.suggest_float('x', -10, 10)
#     return (x - 3)**2 + 1
#
# # Run Bayesian Optimization using Optuna
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=50)
#
# print("Best parameters from Optuna:", study.best_params)
# ```

# %%
import optuna

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score   
 
# load and preprocess dataset
data = load_breast_cancer()
x, y = data.data, data.target

# split dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=7)

# standardize features
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.fit_transform(x_test)

print(f"Training Dataset: {x_train.shape}") 
print(f"Test Dataset: {x_test.shape}")
# Out:
# Training Dataset: (398, 30)
# Test Dataset: (171, 30)

# %%
# Define baseline XGBOOST model

# train baseline 
baseline_model = XGBClassifier(eval_metric = 'logloss', random_state=7)
baseline_model.fit(x_train, y_train)

# Evaluate model
baseline_pred= baseline_model.predict(x_test)
baseline_accuracy = accuracy_score(y_test, baseline_pred)

print(f"XGBoost Accuracy: {baseline_accuracy:.4f}")
# Out:
# XGBoost Accuracy: 0.9591

# %%
def objective(trial):
    # Compute scale_pos_weight to handle class imbalance
    pos = sum(y_train == 1)
    neg = sum(y_train == 0)
    scale_pos_weight = neg / pos

    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'scale_pos_weight': scale_pos_weight
    }

    model = XGBClassifier(eval_metric='logloss', random_state=7, use_label_encoder=False, **params)
    
    # 5-fold cross-validation using accuracy
    score = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy').mean()
    return score

# Create and optimize the study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Best results
print("Best Hyperparameters: ", study.best_params)
print("Best Accuracy: ", study.best_value)
# Out:
# [I 2025-05-29 22:22:54,600] A new study created in memory with name: no-name-b0208057-cb3c-450b-8232-5c4f9a7acc5e
# [I 2025-05-29 22:22:55,911] Trial 0 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 438, 'max_depth': 89, 'learning_rate': 0.29849837507030175, 'subsample': 0.707739710080838, 'colsample_bytree': 0.7420400448003868, 'gamma': 1.189939368070974, 'reg_alpha': 7.6858627672766975, 'reg_lambda': 4.675515109036943}. Best is trial 0 with value: 0.9397151898734177.
# [I 2025-05-29 22:22:56,973] Trial 1 finished with value: 0.9296835443037974 and parameters: {'n_estimators': 415, 'max_depth': 92, 'learning_rate': 0.1739999041224506, 'subsample': 0.9172564486773785, 'colsample_bytree': 0.6118839047616612, 'gamma': 2.8909186578955643, 'reg_alpha': 6.223521447731558, 'reg_lambda': 1.6193277132824313}. Best is trial 0 with value: 0.9397151898734177.
# [I 2025-05-29 22:22:57,902] Trial 2 finished with value: 0.9422151898734177 and parameters: {'n_estimators': 290, 'max_depth': 54, 'learning_rate': 0.09385040209650165, 'subsample': 0.8583169066550929, 'colsample_bytree': 0.7332653120534278, 'gamma': 0.7394534190137431, 'reg_alpha': 8.574034135294003, 'reg_lambda': 2.2121452711712495}. Best is trial 2 with value: 0.9422151898734177.
# [I 2025-05-29 22:22:59,001] Trial 3 finished with value: 0.9296835443037974 and parameters: {'n_estimators': 458, 'max_depth': 56, 'learning_rate': 0.2307542864918591, 'subsample': 0.69454237083164, 'colsample_bytree': 0.9354367564866372, 'gamma': 4.676643089428919, 'reg_alpha': 4.18264838334329, 'reg_lambda': 8.603029703518631}. Best is trial 2 with value: 0.9422151898734177.
# [I 2025-05-29 22:23:00,083] Trial 4 finished with value: 0.9472784810126583 and parameters: {'n_estimators': 402, 'max_depth': 13, 'learning_rate': 0.2768481036933836, 'subsample': 0.8793341019390961, 'colsample_bytree': 0.7795064312263726, 'gamma': 1.2410419660552114, 'reg_alpha': 1.802825346607455, 'reg_lambda': 1.8498719011094156}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:00,986] Trial 5 finished with value: 0.9347151898734177 and parameters: {'n_estimators': 113, 'max_depth': 68, 'learning_rate': 0.023439908139008626, 'subsample': 0.9144906374498186, 'colsample_bytree': 0.8990200261932816, 'gamma': 0.8268367222943018, 'reg_alpha': 8.71554622634892, 'reg_lambda': 1.7279086247397057}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:01,804] Trial 6 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 246, 'max_depth': 40, 'learning_rate': 0.07400507873712305, 'subsample': 0.8173897654554294, 'colsample_bytree': 0.7889939037190609, 'gamma': 2.3576886190269155, 'reg_alpha': 4.156652783922, 'reg_lambda': 9.306387876665939}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:03,038] Trial 7 finished with value: 0.942246835443038 and parameters: {'n_estimators': 499, 'max_depth': 74, 'learning_rate': 0.2955796473941123, 'subsample': 0.997212155237181, 'colsample_bytree': 0.6012999050812354, 'gamma': 2.2857152594918073, 'reg_alpha': 0.18563266344775675, 'reg_lambda': 7.605122505551164}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:04,152] Trial 8 finished with value: 0.9347151898734177 and parameters: {'n_estimators': 433, 'max_depth': 100, 'learning_rate': 0.05448806866562611, 'subsample': 0.8098331254205846, 'colsample_bytree': 0.6977245448344345, 'gamma': 1.8785570323061096, 'reg_alpha': 6.3877819476243225, 'reg_lambda': 9.335383193189314}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:05,265] Trial 9 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 316, 'max_depth': 39, 'learning_rate': 0.058338544941096825, 'subsample': 0.708846436305056, 'colsample_bytree': 0.8647883868280768, 'gamma': 0.8663135190668814, 'reg_alpha': 7.06818950057518, 'reg_lambda': 2.6746661863275554}. Best is trial 4 with value: 0.9472784810126583.
# [I 2025-05-29 22:23:06,022] Trial 10 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 184, 'max_depth': 3, 'learning_rate': 0.21479807033006348, 'subsample': 0.6182651670986348, 'colsample_bytree': 0.8369580816317317, 'gamma': 0.027040886396196617, 'reg_alpha': 1.2401073207529256, 'reg_lambda': 0.0023495987879129654}. Best is trial 10 with value: 0.9547784810126583.
# [I 2025-05-29 22:23:06,672] Trial 11 finished with value: 0.9573101265822783 and parameters: {'n_estimators': 156, 'max_depth': 3, 'learning_rate': 0.22474701849894782, 'subsample': 0.6146022697552932, 'colsample_bytree': 0.9913584864299577, 'gamma': 0.24651534220784405, 'reg_alpha': 1.1819849153180415, 'reg_lambda': 0.4349866581272379}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:07,365] Trial 12 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 128, 'max_depth': 4, 'learning_rate': 0.17950625015486493, 'subsample': 0.6193818179355501, 'colsample_bytree': 0.9903580423394348, 'gamma': 0.07296757115374142, 'reg_alpha': 1.9390127110590794, 'reg_lambda': 0.2203316286577111}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:08,011] Trial 13 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 181, 'max_depth': 22, 'learning_rate': 0.22186684488508535, 'subsample': 0.613480446701887, 'colsample_bytree': 0.8521512775930145, 'gamma': 3.646545958479355, 'reg_alpha': 0.013124818444420372, 'reg_lambda': 0.2293047806749593}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:08,551] Trial 14 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 62, 'max_depth': 26, 'learning_rate': 0.1251416954674217, 'subsample': 0.6674825530719399, 'colsample_bytree': 0.9362018177589302, 'gamma': 0.06399786585199027, 'reg_alpha': 2.1558726477352854, 'reg_lambda': 4.182847641351298}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:09,394] Trial 15 finished with value: 0.9472151898734177 and parameters: {'n_estimators': 221, 'max_depth': 3, 'learning_rate': 0.22985344056067278, 'subsample': 0.7486123925974629, 'colsample_bytree': 0.8411609314927705, 'gamma': 0.04595186131960022, 'reg_alpha': 3.2313260076498054, 'reg_lambda': 3.435452663537805}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:10,091] Trial 16 finished with value: 0.9347151898734177 and parameters: {'n_estimators': 173, 'max_depth': 23, 'learning_rate': 0.20041736104610602, 'subsample': 0.602218795327386, 'colsample_bytree': 0.9858339575067494, 'gamma': 3.140827076993897, 'reg_alpha': 1.092145180708889, 'reg_lambda': 6.314526461223445}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:11,212] Trial 17 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 356, 'max_depth': 35, 'learning_rate': 0.14451473976482332, 'subsample': 0.7612922747216235, 'colsample_bytree': 0.6542030819121569, 'gamma': 1.6185113221875007, 'reg_alpha': 2.9625758786712275, 'reg_lambda': 0.48905860505255394}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:11,675] Trial 18 finished with value: 0.9322151898734177 and parameters: {'n_estimators': 55, 'max_depth': 13, 'learning_rate': 0.2539734741419063, 'subsample': 0.6573077598383894, 'colsample_bytree': 0.9215786001468967, 'gamma': 0.49870413256693547, 'reg_alpha': 9.86108808326719, 'reg_lambda': 5.847851813683297}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:12,266] Trial 19 finished with value: 0.9271518987341771 and parameters: {'n_estimators': 182, 'max_depth': 14, 'learning_rate': 0.19397313206703456, 'subsample': 0.6529215651522904, 'colsample_bytree': 0.8266815362304616, 'gamma': 4.988942963728663, 'reg_alpha': 5.218605278218284, 'reg_lambda': 0.9474519810320268}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:12,777] Trial 20 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 125, 'max_depth': 31, 'learning_rate': 0.25698121287947623, 'subsample': 0.7697115081368828, 'colsample_bytree': 0.964190241638917, 'gamma': 1.7945320582543838, 'reg_alpha': 0.9622535050341527, 'reg_lambda': 3.164559330378226}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:13,443] Trial 21 finished with value: 0.9447784810126583 and parameters: {'n_estimators': 123, 'max_depth': 4, 'learning_rate': 0.15632610089015747, 'subsample': 0.6265924963090808, 'colsample_bytree': 0.9947250015523393, 'gamma': 0.3296806111015481, 'reg_alpha': 2.4733761625091013, 'reg_lambda': 0.02002489219140602}. Best is trial 11 with value: 0.9573101265822783.
# [I 2025-05-29 22:23:14,371] Trial 22 finished with value: 0.9623417721518986 and parameters: {'n_estimators': 230, 'max_depth': 6, 'learning_rate': 0.18980284512611548, 'subsample': 0.6396626578705434, 'colsample_bytree': 0.8953884937679862, 'gamma': 0.07112505010552457, 'reg_alpha': 1.5964442119016944, 'reg_lambda': 0.7739122436890957}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:15,160] Trial 23 finished with value: 0.9523101265822784 and parameters: {'n_estimators': 216, 'max_depth': 14, 'learning_rate': 0.21208109689061658, 'subsample': 0.6677699219492532, 'colsample_bytree': 0.8931344625787465, 'gamma': 1.2101165799962872, 'reg_alpha': 1.031805684081942, 'reg_lambda': 1.1056482608076428}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:16,055] Trial 24 finished with value: 0.9421835443037974 and parameters: {'n_estimators': 264, 'max_depth': 10, 'learning_rate': 0.2510330645798197, 'subsample': 0.6399315998854019, 'colsample_bytree': 0.8797633938149979, 'gamma': 0.5740533363917071, 'reg_alpha': 3.4389293480982897, 'reg_lambda': 1.1058579882101454}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:16,745] Trial 25 finished with value: 0.9447784810126583 and parameters: {'n_estimators': 165, 'max_depth': 21, 'learning_rate': 0.13932790340894655, 'subsample': 0.7246724047765516, 'colsample_bytree': 0.8186260494179379, 'gamma': 0.4031687271725887, 'reg_alpha': 1.521166012283211, 'reg_lambda': 2.719215481899603}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:17,417] Trial 26 finished with value: 0.9422784810126583 and parameters: {'n_estimators': 215, 'max_depth': 44, 'learning_rate': 0.1729619687125532, 'subsample': 0.6000543754175075, 'colsample_bytree': 0.9479127902783627, 'gamma': 3.8413682802706917, 'reg_alpha': 0.5900123140197937, 'reg_lambda': 3.873047316451096}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:18,486] Trial 27 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 330, 'max_depth': 29, 'learning_rate': 0.19397030819350203, 'subsample': 0.6859884380241159, 'colsample_bytree': 0.9093880551325955, 'gamma': 1.0936577166033765, 'reg_alpha': 4.697450533601387, 'reg_lambda': 1.0903749459120038}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:19,007] Trial 28 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 101, 'max_depth': 18, 'learning_rate': 0.11017359443019112, 'subsample': 0.6402042968851569, 'colsample_bytree': 0.7642341237247163, 'gamma': 1.5342432200741325, 'reg_alpha': 2.5874522756295106, 'reg_lambda': 2.3493120820971862}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:19,628] Trial 29 finished with value: 0.9447151898734176 and parameters: {'n_estimators': 150, 'max_depth': 8, 'learning_rate': 0.2778361538600834, 'subsample': 0.7215997081030426, 'colsample_bytree': 0.812002779484788, 'gamma': 0.3182015745581982, 'reg_alpha': 1.4474351681863649, 'reg_lambda': 5.1352366697770275}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:20,504] Trial 30 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 243, 'max_depth': 64, 'learning_rate': 0.2394728661759447, 'subsample': 0.6897269446585966, 'colsample_bytree': 0.9694583266932408, 'gamma': 1.0198271170907327, 'reg_alpha': 3.6288597223283734, 'reg_lambda': 0.6826374151603483}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:21,249] Trial 31 finished with value: 0.9497784810126584 and parameters: {'n_estimators': 206, 'max_depth': 17, 'learning_rate': 0.2135888405170103, 'subsample': 0.667074216958025, 'colsample_bytree': 0.8810033438550509, 'gamma': 1.368837971437941, 'reg_alpha': 0.5517896231256326, 'reg_lambda': 1.2681907097306195}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:22,322] Trial 32 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 286, 'max_depth': 8, 'learning_rate': 0.2129850562010977, 'subsample': 0.6325715741342159, 'colsample_bytree': 0.8870449149589359, 'gamma': 0.047100082471350356, 'reg_alpha': 1.0345747910635343, 'reg_lambda': 1.6925539217840595}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:23,431] Trial 33 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 289, 'max_depth': 8, 'learning_rate': 0.16679123393685588, 'subsample': 0.633683069765831, 'colsample_bytree': 0.8559322002243479, 'gamma': 0.03290451883095277, 'reg_alpha': 2.555916306365221, 'reg_lambda': 1.8244137833213092}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:24,264] Trial 34 finished with value: 0.9597784810126582 and parameters: {'n_estimators': 264, 'max_depth': 4, 'learning_rate': 0.18476066124605806, 'subsample': 0.600993992602873, 'colsample_bytree': 0.7251927475324398, 'gamma': 0.6166231971709366, 'reg_alpha': 0.5618579812670064, 'reg_lambda': 0.056365934528338935}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:25,082] Trial 35 finished with value: 0.9472784810126583 and parameters: {'n_estimators': 258, 'max_depth': 3, 'learning_rate': 0.18561129996013043, 'subsample': 0.6011782456548429, 'colsample_bytree': 0.721411121464964, 'gamma': 0.6831327498498122, 'reg_alpha': 1.7848732676556431, 'reg_lambda': 0.08423477347586834}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:26,091] Trial 36 finished with value: 0.952246835443038 and parameters: {'n_estimators': 350, 'max_depth': 17, 'learning_rate': 0.15790037606785765, 'subsample': 0.9985283249151236, 'colsample_bytree': 0.6702087158099772, 'gamma': 0.6200063756839274, 'reg_alpha': 0.028809290607556104, 'reg_lambda': 0.6743701894212284}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:26,808] Trial 37 finished with value: 0.9497784810126584 and parameters: {'n_estimators': 198, 'max_depth': 78, 'learning_rate': 0.23981749769519034, 'subsample': 0.6802389461391858, 'colsample_bytree': 0.778884639815559, 'gamma': 0.888972177697722, 'reg_alpha': 0.5947472774147833, 'reg_lambda': 2.1396978882430924}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:27,619] Trial 38 finished with value: 0.9421835443037974 and parameters: {'n_estimators': 235, 'max_depth': 47, 'learning_rate': 0.27116227184083436, 'subsample': 0.8440015911558002, 'colsample_bytree': 0.7424766059539613, 'gamma': 0.38149421707196557, 'reg_alpha': 5.6045456977490735, 'reg_lambda': 1.3873450667792}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:28,205] Trial 39 finished with value: 0.9321202531645569 and parameters: {'n_estimators': 152, 'max_depth': 10, 'learning_rate': 0.2063515171420754, 'subsample': 0.6444696338670779, 'colsample_bytree': 0.7534547408005874, 'gamma': 2.0690761058921683, 'reg_alpha': 3.9644843703146813, 'reg_lambda': 7.312293980049291}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:29,162] Trial 40 finished with value: 0.9472784810126582 and parameters: {'n_estimators': 315, 'max_depth': 28, 'learning_rate': 0.22773409724993904, 'subsample': 0.6244870473673756, 'colsample_bytree': 0.7214528294909385, 'gamma': 0.27666501216233796, 'reg_alpha': 1.3778182319745897, 'reg_lambda': 0.616784152432191}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:30,149] Trial 41 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 280, 'max_depth': 6, 'learning_rate': 0.18695612256515895, 'subsample': 0.6234520378333904, 'colsample_bytree': 0.9161396085240181, 'gamma': 0.23478027914655936, 'reg_alpha': 0.6137936027140052, 'reg_lambda': 1.6961999734775628}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:30,603] Trial 42 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 91, 'max_depth': 10, 'learning_rate': 0.21573326488102915, 'subsample': 0.6515174804577687, 'colsample_bytree': 0.6306769393370593, 'gamma': 0.7159573816726599, 'reg_alpha': 1.8705502757732182, 'reg_lambda': 0.5496748090699943}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:31,601] Trial 43 finished with value: 0.9396835443037975 and parameters: {'n_estimators': 388, 'max_depth': 12, 'learning_rate': 0.1718819569343288, 'subsample': 0.7000384111039464, 'colsample_bytree': 0.8047337434198009, 'gamma': 2.882339660861196, 'reg_alpha': 0.9781883903581274, 'reg_lambda': 0.03726926069320946}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:32,651] Trial 44 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 305, 'max_depth': 3, 'learning_rate': 0.2007521892586306, 'subsample': 0.616036197569284, 'colsample_bytree': 0.8746718101492659, 'gamma': 0.04677898352893378, 'reg_alpha': 2.1725743336728582, 'reg_lambda': 1.5196094698983462}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:33,516] Trial 45 finished with value: 0.9371835443037975 and parameters: {'n_estimators': 236, 'max_depth': 19, 'learning_rate': 0.23970982062593715, 'subsample': 0.9256473144836737, 'colsample_bytree': 0.8339224613601426, 'gamma': 0.5314741771508846, 'reg_alpha': 0.3528330194006778, 'reg_lambda': 2.162072336534131}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:34,321] Trial 46 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 268, 'max_depth': 24, 'learning_rate': 0.2207587686985356, 'subsample': 0.6739704144240737, 'colsample_bytree': 0.9362471019600447, 'gamma': 0.8943271052318118, 'reg_alpha': 1.3054885728245575, 'reg_lambda': 2.639894511458155}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:35,481] Trial 47 finished with value: 0.9447784810126583 and parameters: {'n_estimators': 195, 'max_depth': 7, 'learning_rate': 0.021320699075501354, 'subsample': 0.6138649904481391, 'colsample_bytree': 0.6944873734569863, 'gamma': 0.21817592578062897, 'reg_alpha': 3.0672999056618386, 'reg_lambda': 0.698690359871671}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:36,459] Trial 48 finished with value: 0.942246835443038 and parameters: {'n_estimators': 298, 'max_depth': 61, 'learning_rate': 0.14588248555984462, 'subsample': 0.9532678681415703, 'colsample_bytree': 0.790611323690395, 'gamma': 0.7839666125741591, 'reg_alpha': 7.981181947654004, 'reg_lambda': 0.4122454922569092}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:37,250] Trial 49 finished with value: 0.942246835443038 and parameters: {'n_estimators': 154, 'max_depth': 15, 'learning_rate': 0.12540599323879628, 'subsample': 0.7208620039204492, 'colsample_bytree': 0.8462395886016647, 'gamma': 0.18146792201976836, 'reg_alpha': 2.2048895188313935, 'reg_lambda': 1.5576180826726804}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:37,679] Trial 50 finished with value: 0.9422151898734177 and parameters: {'n_estimators': 79, 'max_depth': 80, 'learning_rate': 0.18751277451167872, 'subsample': 0.7942753168518291, 'colsample_bytree': 0.864668963298909, 'gamma': 4.238047845393522, 'reg_alpha': 1.77870473616661, 'reg_lambda': 3.064020534514963}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:38,461] Trial 51 finished with value: 0.9523101265822784 and parameters: {'n_estimators': 225, 'max_depth': 13, 'learning_rate': 0.20721160611467754, 'subsample': 0.6609909904352934, 'colsample_bytree': 0.9120637840750939, 'gamma': 1.2964027617918414, 'reg_alpha': 0.8953808836703518, 'reg_lambda': 1.166820747422823}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:39,334] Trial 52 finished with value: 0.9597784810126582 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.2091088016499369, 'subsample': 0.6384539197718833, 'colsample_bytree': 0.8892776748358618, 'gamma': 0.4805281711733676, 'reg_alpha': 0.9669191480367416, 'reg_lambda': 1.1058078191883192}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:40,168] Trial 53 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 252, 'max_depth': 7, 'learning_rate': 0.2281130196446274, 'subsample': 0.6382856997448861, 'colsample_bytree': 0.9663871785507374, 'gamma': 0.007570048243313567, 'reg_alpha': 0.2289213190370114, 'reg_lambda': 0.0068068696332392875}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:41,062] Trial 54 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 278, 'max_depth': 34, 'learning_rate': 0.26638979094473925, 'subsample': 0.6095876825652023, 'colsample_bytree': 0.9005881196919718, 'gamma': 0.4866161342670217, 'reg_alpha': 1.337331927841135, 'reg_lambda': 0.8482806081434273}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:41,784] Trial 55 finished with value: 0.9573101265822785 and parameters: {'n_estimators': 189, 'max_depth': 6, 'learning_rate': 0.20019646862520904, 'subsample': 0.6264468103831377, 'colsample_bytree': 0.8885720415602852, 'gamma': 1.0299251664142193, 'reg_alpha': 0.8628024190481154, 'reg_lambda': 1.941464601717339}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:42,351] Trial 56 finished with value: 0.9472784810126582 and parameters: {'n_estimators': 138, 'max_depth': 4, 'learning_rate': 0.19655413635429844, 'subsample': 0.654455672797173, 'colsample_bytree': 0.9432747611155423, 'gamma': 1.0566088454573512, 'reg_alpha': 1.6385157185072847, 'reg_lambda': 0.3419402993135289}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:43,103] Trial 57 finished with value: 0.9472784810126582 and parameters: {'n_estimators': 193, 'max_depth': 21, 'learning_rate': 0.1794865425977329, 'subsample': 0.6215764167795116, 'colsample_bytree': 0.9265831544984837, 'gamma': 0.46437620716740213, 'reg_alpha': 2.7556213133712895, 'reg_lambda': 1.9818594945555505}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:43,934] Trial 58 finished with value: 0.939746835443038 and parameters: {'n_estimators': 174, 'max_depth': 93, 'learning_rate': 0.16727273156259737, 'subsample': 0.7082447870055187, 'colsample_bytree': 0.9536200417947583, 'gamma': 2.611093617693466, 'reg_alpha': 0.018454459010663338, 'reg_lambda': 8.677099465568437}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:44,853] Trial 59 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 228, 'max_depth': 11, 'learning_rate': 0.23975187215846322, 'subsample': 0.7454413203660277, 'colsample_bytree': 0.8304462898623935, 'gamma': 1.4644943877380814, 'reg_alpha': 0.7693724675402851, 'reg_lambda': 0.9504942161655898}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:45,646] Trial 60 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 168, 'max_depth': 7, 'learning_rate': 0.15788199996787874, 'subsample': 0.6468568720047914, 'colsample_bytree': 0.8635505693625172, 'gamma': 1.7430391941827255, 'reg_alpha': 2.31468507402566, 'reg_lambda': 0.3196088673351815}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:46,626] Trial 61 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 214, 'max_depth': 6, 'learning_rate': 0.20398285384862105, 'subsample': 0.6293871768156084, 'colsample_bytree': 0.8830001295865137, 'gamma': 0.27395053530551483, 'reg_alpha': 1.138267633022514, 'reg_lambda': 1.3645128670496895}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:47,496] Trial 62 finished with value: 0.9573101265822785 and parameters: {'n_estimators': 251, 'max_depth': 3, 'learning_rate': 0.21917891783987148, 'subsample': 0.6004107010310739, 'colsample_bytree': 0.902962476576832, 'gamma': 0.6028149625427847, 'reg_alpha': 0.3965983086275837, 'reg_lambda': 2.610832223989854}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:48,414] Trial 63 finished with value: 0.9347784810126584 and parameters: {'n_estimators': 259, 'max_depth': 3, 'learning_rate': 0.21930027261832583, 'subsample': 0.6002392205503534, 'colsample_bytree': 0.9846933622503523, 'gamma': 0.6666607952152824, 'reg_alpha': 6.771874654226058, 'reg_lambda': 4.715900412287201}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:49,113] Trial 64 finished with value: 0.9598417721518986 and parameters: {'n_estimators': 188, 'max_depth': 14, 'learning_rate': 0.2521988200529953, 'subsample': 0.6111338532647963, 'colsample_bytree': 0.9030868346087659, 'gamma': 0.9353154497913878, 'reg_alpha': 0.4520986347381999, 'reg_lambda': 2.5215612045871474}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:50,736] Trial 65 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 496, 'max_depth': 14, 'learning_rate': 0.2838287330734655, 'subsample': 0.6065684653999894, 'colsample_bytree': 0.9027702649837339, 'gamma': 0.914745429377052, 'reg_alpha': 0.46383448900161106, 'reg_lambda': 3.716163545585076}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:51,548] Trial 66 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 245, 'max_depth': 16, 'learning_rate': 0.2510824557937197, 'subsample': 0.6128873519962211, 'colsample_bytree': 0.8943658756260512, 'gamma': 1.140039702434341, 'reg_alpha': 0.32235688607413104, 'reg_lambda': 2.4780569146453106}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:52,283] Trial 67 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 210, 'max_depth': 11, 'learning_rate': 0.2973018086419782, 'subsample': 0.6358822748478856, 'colsample_bytree': 0.9246713270026128, 'gamma': 0.7765952868369568, 'reg_alpha': 0.7247187266152284, 'reg_lambda': 2.7880805180381696}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:52,911] Trial 68 finished with value: 0.939746835443038 and parameters: {'n_estimators': 134, 'max_depth': 10, 'learning_rate': 0.2341393759549633, 'subsample': 0.6609383947934032, 'colsample_bytree': 0.99922798444895, 'gamma': 0.9918960114989754, 'reg_alpha': 1.5648173968513224, 'reg_lambda': 3.2038284450538335}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:53,658] Trial 69 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 190, 'max_depth': 18, 'learning_rate': 0.2474553361948065, 'subsample': 0.6763823316724334, 'colsample_bytree': 0.927668134179785, 'gamma': 0.5594586017698515, 'reg_alpha': 0.2986665612010445, 'reg_lambda': 4.357844625876634}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:54,986] Trial 70 finished with value: 0.9397151898734177 and parameters: {'n_estimators': 333, 'max_depth': 52, 'learning_rate': 0.2603642066150928, 'subsample': 0.8836971669851351, 'colsample_bytree': 0.8698571153457849, 'gamma': 1.9703170715458338, 'reg_alpha': 2.0074426520041238, 'reg_lambda': 2.0701000118757147}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:55,722] Trial 71 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 184, 'max_depth': 5, 'learning_rate': 0.19228837002677052, 'subsample': 0.6229690228933445, 'colsample_bytree': 0.8526226000745739, 'gamma': 0.3854879651405076, 'reg_alpha': 1.1803783796335015, 'reg_lambda': 0.8140965536709391}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:56,662] Trial 72 finished with value: 0.9548101265822785 and parameters: {'n_estimators': 204, 'max_depth': 3, 'learning_rate': 0.17925049175120686, 'subsample': 0.6443536992860213, 'colsample_bytree': 0.8906189213532923, 'gamma': 0.15478268215106208, 'reg_alpha': 0.8668844690832466, 'reg_lambda': 9.97271974357235}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:57,581] Trial 73 finished with value: 0.9548101265822785 and parameters: {'n_estimators': 201, 'max_depth': 9, 'learning_rate': 0.18177197591213953, 'subsample': 0.642971782431421, 'colsample_bytree': 0.8932032597907387, 'gamma': 0.20437288429390477, 'reg_alpha': 0.7905519470236926, 'reg_lambda': 7.420038932694011}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:58,164] Trial 74 finished with value: 0.9347468354430379 and parameters: {'n_estimators': 159, 'max_depth': 6, 'learning_rate': 0.22546669517176102, 'subsample': 0.6289256519388127, 'colsample_bytree': 0.9585114474921157, 'gamma': 0.6109271905407851, 'reg_alpha': 9.825950802292159, 'reg_lambda': 9.570374502964501}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:23:59,072] Trial 75 finished with value: 0.9573417721518988 and parameters: {'n_estimators': 229, 'max_depth': 3, 'learning_rate': 0.20895754100768532, 'subsample': 0.6071809084854429, 'colsample_bytree': 0.9778852883235416, 'gamma': 0.39000727207535796, 'reg_alpha': 0.502103330160917, 'reg_lambda': 5.424268085242651}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:00,054] Trial 76 finished with value: 0.9472784810126583 and parameters: {'n_estimators': 235, 'max_depth': 13, 'learning_rate': 0.20483725486112905, 'subsample': 0.6112255880147917, 'colsample_bytree': 0.9758386629708129, 'gamma': 1.248371528507697, 'reg_alpha': 0.0551285086742751, 'reg_lambda': 3.720481839926956}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:01,049] Trial 77 finished with value: 0.9598417721518986 and parameters: {'n_estimators': 270, 'max_depth': 20, 'learning_rate': 0.19509991048051203, 'subsample': 0.6030488321391271, 'colsample_bytree': 0.9799003724773254, 'gamma': 0.4484242453890891, 'reg_alpha': 0.36451623775028275, 'reg_lambda': 5.718101328972862}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:01,906] Trial 78 finished with value: 0.9548101265822785 and parameters: {'n_estimators': 272, 'max_depth': 21, 'learning_rate': 0.19507663474691744, 'subsample': 0.6030871066730338, 'colsample_bytree': 0.9365185928063157, 'gamma': 0.7957914774168724, 'reg_alpha': 0.42793206249296234, 'reg_lambda': 5.9971100135867506}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:02,869] Trial 79 finished with value: 0.9523101265822784 and parameters: {'n_estimators': 244, 'max_depth': 15, 'learning_rate': 0.2129460394570919, 'subsample': 0.6208627027560533, 'colsample_bytree': 0.977059459455374, 'gamma': 0.43805292690697134, 'reg_alpha': 0.5459037054342717, 'reg_lambda': 5.7389423131630055}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:03,825] Trial 80 finished with value: 0.9472784810126583 and parameters: {'n_estimators': 265, 'max_depth': 27, 'learning_rate': 0.16498046799431687, 'subsample': 0.6003142346913217, 'colsample_bytree': 0.9113388422261703, 'gamma': 0.6764155851639672, 'reg_alpha': 1.5203547898286587, 'reg_lambda': 6.770093190110841}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:04,576] Trial 81 finished with value: 0.9548101265822785 and parameters: {'n_estimators': 221, 'max_depth': 9, 'learning_rate': 0.22303775364360892, 'subsample': 0.6118063817026137, 'colsample_bytree': 0.9491814503877224, 'gamma': 0.38895020282655196, 'reg_alpha': 1.1585070124700905, 'reg_lambda': 5.255550481791039}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:06,559] Trial 82 finished with value: 0.9372151898734178 and parameters: {'n_estimators': 256, 'max_depth': 5, 'learning_rate': 0.010956348504128272, 'subsample': 0.6338967174249994, 'colsample_bytree': 0.985118748296585, 'gamma': 0.9522748026874466, 'reg_alpha': 0.26719293438176184, 'reg_lambda': 6.406045755232789}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:07,489] Trial 83 finished with value: 0.9472784810126582 and parameters: {'n_estimators': 299, 'max_depth': 11, 'learning_rate': 0.20020808960860279, 'subsample': 0.617762215356844, 'colsample_bytree': 0.9616637328900736, 'gamma': 0.5390343455866292, 'reg_alpha': 0.7836051591177835, 'reg_lambda': 5.2912769630187775}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:08,148] Trial 84 finished with value: 0.9497784810126582 and parameters: {'n_estimators': 113, 'max_depth': 8, 'learning_rate': 0.23443210102205023, 'subsample': 0.6296753453031994, 'colsample_bytree': 0.993119985120386, 'gamma': 0.32872448965121803, 'reg_alpha': 1.0186896548508155, 'reg_lambda': 5.469529970756526}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:08,897] Trial 85 finished with value: 0.9548101265822785 and parameters: {'n_estimators': 143, 'max_depth': 24, 'learning_rate': 0.24595623338090913, 'subsample': 0.6542573906634659, 'colsample_bytree': 0.9744230652186192, 'gamma': 0.15955239760640916, 'reg_alpha': 0.5852535444137649, 'reg_lambda': 4.822693157842674}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:09,602] Trial 86 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.21350487558572961, 'subsample': 0.6669412658301578, 'colsample_bytree': 0.694774698402184, 'gamma': 0.788746383174284, 'reg_alpha': 1.7129379998063254, 'reg_lambda': 2.3970302284711336}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:10,283] Trial 87 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 177, 'max_depth': 12, 'learning_rate': 0.18762186261556887, 'subsample': 0.6130552856389309, 'colsample_bytree': 0.9399171888485514, 'gamma': 0.6143328965990796, 'reg_alpha': 0.10729459691748316, 'reg_lambda': 1.7998143082058857}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:11,103] Trial 88 finished with value: 0.9346835443037975 and parameters: {'n_estimators': 285, 'max_depth': 40, 'learning_rate': 0.07338825595617664, 'subsample': 0.6474089836071597, 'colsample_bytree': 0.6681754172750551, 'gamma': 3.478773452944779, 'reg_alpha': 1.3187344404515495, 'reg_lambda': 4.1726734681453195}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:11,994] Trial 89 finished with value: 0.942246835443038 and parameters: {'n_estimators': 248, 'max_depth': 8, 'learning_rate': 0.17472963141888087, 'subsample': 0.6361179814601468, 'colsample_bytree': 0.9197459415472949, 'gamma': 1.110063414365659, 'reg_alpha': 1.9594390730864473, 'reg_lambda': 6.150355417514436}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:13,040] Trial 90 finished with value: 0.9472468354430379 and parameters: {'n_estimators': 316, 'max_depth': 19, 'learning_rate': 0.20755302211079035, 'subsample': 0.6231859175532772, 'colsample_bytree': 0.9052533253984979, 'gamma': 1.3982679557972713, 'reg_alpha': 0.9499946017296013, 'reg_lambda': 5.5973624937737085}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:14,433] Trial 91 finished with value: 0.9598417721518986 and parameters: {'n_estimators': 207, 'max_depth': 3, 'learning_rate': 0.19113274223010787, 'subsample': 0.6076008984360657, 'colsample_bytree': 0.888408294572834, 'gamma': 0.15117063866331157, 'reg_alpha': 0.7900706974211392, 'reg_lambda': 7.967815803986246}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:15,831] Trial 92 finished with value: 0.952246835443038 and parameters: {'n_estimators': 217, 'max_depth': 4, 'learning_rate': 0.19097625928546014, 'subsample': 0.607099605646314, 'colsample_bytree': 0.8757063085558352, 'gamma': 0.12329097267319494, 'reg_alpha': 0.46350288610684864, 'reg_lambda': 8.092585909973593}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:16,754] Trial 93 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 238, 'max_depth': 6, 'learning_rate': 0.21842130405305285, 'subsample': 0.6158559560837977, 'colsample_bytree': 0.8433759221968514, 'gamma': 0.27478649607519723, 'reg_alpha': 0.6812395468658549, 'reg_lambda': 2.9404238628209844}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:17,591] Trial 94 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 188, 'max_depth': 9, 'learning_rate': 0.20002561566211655, 'subsample': 0.6279154925231692, 'colsample_bytree': 0.8567034293336252, 'gamma': 0.4210807790250445, 'reg_alpha': 0.24783440531580203, 'reg_lambda': 8.44542330786186}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:18,803] Trial 95 finished with value: 0.9547784810126583 and parameters: {'n_estimators': 273, 'max_depth': 16, 'learning_rate': 0.23070491396967893, 'subsample': 0.6074497593393874, 'colsample_bytree': 0.8176246912616806, 'gamma': 0.0062491373459695465, 'reg_alpha': 1.4131804874187899, 'reg_lambda': 6.995128493338352}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:19,485] Trial 96 finished with value: 0.9447468354430381 and parameters: {'n_estimators': 164, 'max_depth': 3, 'learning_rate': 0.18072002832677994, 'subsample': 0.621928703241913, 'colsample_bytree': 0.8837825305592221, 'gamma': 0.4862736353528803, 'reg_alpha': 5.874211417951724, 'reg_lambda': 1.010627943147504}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:20,382] Trial 97 finished with value: 0.9522784810126582 and parameters: {'n_estimators': 210, 'max_depth': 13, 'learning_rate': 0.1517051288813463, 'subsample': 0.6023007927247193, 'colsample_bytree': 0.9319169287083621, 'gamma': 0.320204311178618, 'reg_alpha': 0.002867457810896923, 'reg_lambda': 1.282772157736777}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:21,294] Trial 98 finished with value: 0.949746835443038 and parameters: {'n_estimators': 253, 'max_depth': 6, 'learning_rate': 0.2100344569807422, 'subsample': 0.6953555390181481, 'colsample_bytree': 0.982191363904597, 'gamma': 0.8655492252940111, 'reg_alpha': 1.14906061976647, 'reg_lambda': 0.5549831840146193}. Best is trial 22 with value: 0.9623417721518986.
# [I 2025-05-29 22:24:22,153] Trial 99 finished with value: 0.9598101265822786 and parameters: {'n_estimators': 224, 'max_depth': 11, 'learning_rate': 0.19753675814485191, 'subsample': 0.8264641562837922, 'colsample_bytree': 0.7789961549100423, 'gamma': 0.15223252945266808, 'reg_alpha': 0.8373909177825456, 'reg_lambda': 0.21676973748506426}. Best is trial 22 with value: 0.9623417721518986.
# Best Hyperparameters:  {'n_estimators': 230, 'max_depth': 6, 'learning_rate': 0.18980284512611548, 'subsample': 0.6396626578705434, 'colsample_bytree': 0.8953884937679862, 'gamma': 0.07112505010552457, 'reg_alpha': 1.5964442119016944, 'reg_lambda': 0.7739122436890957}
# Best Accuracy:  0.9623417721518986

# %%
# Define parameter grid 
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth':[3,5,7],
    'learning_rate':[0.01, 0.1, 0.2],
    'subsample':[0.6, 0.8, 1.0]
}

# train xgboost with grid search

grid_search = GridSearchCV(
    estimator=XGBClassifier(eval_metrics ='logloss', random_state = 7),
    param_grid= param_grid,
    scoring='accuracy',
    cv=3,
    verbose=1   
)

grid_search.fit(x_train, y_train)

# Best parameters and accuracy
print(f"Grid Search Best Parameters: {grid_search.best_params_}")
print(f"Grid Search Best Score: {grid_search.best_score_}")
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# Grid Search Best Parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.6}
# Grid Search Best Score: 0.9548492443229285

# %%
# Define parameter grid 
param_dist= {
    'n_estimators': [100, 200, 300, 400],
    'max_depth':[3,5,7, 9],
    'learning_rate':[0.01, 0.05, 0.1, 0.2],
    'subsample':[0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0]
}

# traib XGBoost with Random Search
random_search = RandomizedSearchCV(
    estimator=XGBClassifier(eval_mmetrics= 'logloss', random_state=7),
    param_distributions=param_dist,
    n_iter=50, 
    scoring='accuracy',
    cv=3,
    verbose=1,
    random_state=7
    
)

random_search.fit(x_train, y_train)

# Best paramaters and accuracy 
print(f"Random Search Best Parameters: {random_search.best_params_}")
print(f"Random Search Best Score: {random_search.best_score_}")
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Random Search Best Parameters: {'subsample': 0.6, 'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# Random Search Best Score: 0.9623680413154098
